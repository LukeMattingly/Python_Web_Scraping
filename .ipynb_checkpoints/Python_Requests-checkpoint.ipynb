# %% [markdown]
# Requests: HTTP library used to get raw HTML

# %%
import requests

# %%
r = requests.get('https://api.github.com/user', auth=('user', 'pass'))

# %%
r.status_code
# Out:
# 403

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# u'{"message":"Maximum number of login attempts exceeded. Please try again later.","documentation_url":"https://developer.github.com/v3"}'

# %%
r.json()
# Out:
# {u'documentation_url': u'https://developer.github.com/v3',
#  u'message': u'Maximum number of login attempts exceeded. Please try again later.'}

# %%
r.content
# Out:
# '{"message":"Maximum number of login attempts exceeded. Please try again later.","documentation_url":"https://developer.github.com/v3"}'

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})

# %%
r = requests.options('http://httpbin.org/get')

# %%
print r.url
# Out:
# http://httpbin.org/get

# %% [markdown]
# Passing Parameters in URLs

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('http://httpbin.org/get', params = payload)

# %%
print(r.url)
# Out:
# http://httpbin.org/get?key2=value2&key1=value1

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.get('https://httpbin.org/get', params = payload)
print(r.url)
# Out:
# https://httpbin.org/get?key2=value2&key2=value3&key1=value1

# %% [markdown]
# Response Content

# %%
r = requests.get('https://api.github.com/events')
#r.text

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.encoding = 'ISO-8859-1'
#r.content

# %% [markdown]
# Binary Response Content

# %%
from PIL import Image
from io import BytesIO

# %%
r.encoding
# Out:
# 'utf-8'

# %%
#r.content is not an image file, hence will not find one
output = BytesIO()
output.flush()
output.seek(0)
i = Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-40-33966cdf5266> in <module>()
#       3 output.flush()
#       4 output.seek(0)
# ----> 5 i = Image.open(BytesIO(r.content))
#
# C:\Users\Kycool13\Anaconda2\lib\site-packages\PIL\Image.pyc in open(fp, mode)
#    2284
#    2285     raise IOError("cannot identify image file %r"
# -> 2286                   % (filename if filename else fp))
#    2287
#    2288 #
#
# IOError: cannot identify image file <_io.BytesIO object at 0x00000000063112B0>

# %% [markdown]
# JSON Response Content

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/22597094?',
#    u'display_login': u'ojha-url',
#    u'gravatar_id': u'',
#    u'id': 22597094,
#    u'login': u'ojha-url',
#    u'url': u'https://api.github.com/users/ojha-url'},
#   u'created_at': u'2017-12-12T02:05:03Z',
#   u'id': u'6974666798',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/22256113?',
#    u'gravatar_id': u'',
#    u'id': 22256113,
#    u'login': u'urbanriskmap',
#    u'url': u'https://api.github.com/orgs/urbanriskmap'},
#   u'payload': {u'before': u'2546f7b7d93d941b74d5c3fd0b1318b3242439d7',
#    u'commits': [{u'author': {u'email': u'mayank.ojha@gmail.com',
#       u'name': u'ojha-url'},
#      u'distinct': True,
#      u'message': u'UI mods to date & slider',
#      u'sha': u'b47a09ff2595b08c9c382224bb2d4797358337a2',
#      u'url': u'https://api.github.com/repos/urbanriskmap/cognicity-analytics/commits/b47a09ff2595b08c9c382224bb2d4797358337a2'},
#     {u'author': {u'email': u'mayank.ojha@gmail.com', u'name': u'ojha-url'},
#      u'distinct': True,
#      u'message': u'Range slider working',
#      u'sha': u'6ee1e1a28803bb40f914526002151d90dfc72ff9',
#      u'url': u'https://api.github.com/repos/urbanriskmap/cognicity-analytics/commits/6ee1e1a28803bb40f914526002151d90dfc72ff9'}],
#    u'distinct_size': 2,
#    u'head': u'6ee1e1a28803bb40f914526002151d90dfc72ff9',
#    u'push_id': 2188013629L,
#    u'ref': u'refs/heads/master',
#    u'size': 2},
#   u'public': True,
#   u'repo': {u'id': 113494014,
#    u'name': u'urbanriskmap/cognicity-analytics',
#    u'url': u'https://api.github.com/repos/urbanriskmap/cognicity-analytics'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/33362191?',
#    u'display_login': u'nimishaniyogi',
#    u'gravatar_id': u'',
#    u'id': 33362191,
#    u'login': u'nimishaniyogi',
#    u'url': u'https://api.github.com/users/nimishaniyogi'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666795',
#   u'payload': {u'before': u'156d45224f2acce932e040d69100de86cf0353b9',
#    u'commits': [{u'author': {u'email': u'33362191+nimishaniyogi@users.noreply.github.com',
#       u'name': u'nimishaniyogi'},
#      u'distinct': True,
#      u'message': u'Update README.md',
#      u'sha': u'2e3477c1413a2ca1c88cf4d0de65beb2842a7df3',
#      u'url': u'https://api.github.com/repos/karmadog/ClassProject780/commits/2e3477c1413a2ca1c88cf4d0de65beb2842a7df3'}],
#    u'distinct_size': 1,
#    u'head': u'2e3477c1413a2ca1c88cf4d0de65beb2842a7df3',
#    u'push_id': 2188013628L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 108048082,
#    u'name': u'karmadog/ClassProject780',
#    u'url': u'https://api.github.com/repos/karmadog/ClassProject780'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/24620069?',
#    u'display_login': u'HankChenCH',
#    u'gravatar_id': u'',
#    u'id': 24620069,
#    u'login': u'HankChenCH',
#    u'url': u'https://api.github.com/users/HankChenCH'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666794',
#   u'payload': {u'before': u'314de933dfbb3c1ffd773917ea59d8acd2d3a65c',
#    u'commits': [{u'author': {u'email': u'372259464@qq.com',
#       u'name': u'HankGHChen'},
#      u'distinct': True,
#      u'message': u'\u663e\u793a\u6d88\u606f\u53d1\u9001\u7684\u65f6\u95f4\uff1b\n\u4fee\u6539\u63a5\u6536\u6d88\u606f\u7684\u5224\u65ad\u51fd\u6570',
#      u'sha': u'ea9f1717753a3c81d806a7f19c2c6c868a71a277',
#      u'url': u'https://api.github.com/repos/HankChenCH/react-shop-manager/commits/ea9f1717753a3c81d806a7f19c2c6c868a71a277'}],
#    u'distinct_size': 1,
#    u'head': u'ea9f1717753a3c81d806a7f19c2c6c868a71a277',
#    u'push_id': 2188013626L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 98244546,
#    u'name': u'HankChenCH/react-shop-manager',
#    u'url': u'https://api.github.com/repos/HankChenCH/react-shop-manager'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/4021012?',
#    u'display_login': u'smaslennikov',
#    u'gravatar_id': u'',
#    u'id': 4021012,
#    u'login': u'smaslennikov',
#    u'url': u'https://api.github.com/users/smaslennikov'},
#   u'created_at': u'2017-12-12T02:05:03Z',
#   u'id': u'6974666793',
#   u'payload': {u'before': u'82a30fcd58441f124679d377d120ef397d05ae9d',
#    u'commits': [{u'author': {u'email': u'travis@travis-ci.org',
#       u'name': u'Travis CI'},
#      u'distinct': True,
#      u'message': u"Can't you see I'm updating the time?",
#      u'sha': u'45f84277a4b567ab39e044f0d9fa769844ab84d2',
#      u'url': u'https://api.github.com/repos/smaslennikov/whattravisisitrightmeow/commits/45f84277a4b567ab39e044f0d9fa769844ab84d2'}],
#    u'distinct_size': 1,
#    u'head': u'45f84277a4b567ab39e044f0d9fa769844ab84d2',
#    u'push_id': 2188013625L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 112947410,
#    u'name': u'smaslennikov/whattravisisitrightmeow',
#    u'url': u'https://api.github.com/repos/smaslennikov/whattravisisitrightmeow'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/153041?',
#    u'display_login': u'staydecent',
#    u'gravatar_id': u'',
#    u'id': 153041,
#    u'login': u'staydecent',
#    u'url': u'https://api.github.com/users/staydecent'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666791',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/4614109?',
#    u'gravatar_id': u'',
#    u'id': 4614109,
#    u'login': u'inputlogic',
#    u'url': u'https://api.github.com/orgs/inputlogic'},
#   u'payload': {u'pusher_type': u'user',
#    u'ref': u'router-fix',
#    u'ref_type': u'branch'},
#   u'public': True,
#   u'repo': {u'id': 86862111,
#    u'name': u'inputlogic/with-preact',
#    u'url': u'https://api.github.com/repos/inputlogic/with-preact'},
#   u'type': u'DeleteEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/29602928?',
#    u'display_login': u'dmagee15',
#    u'gravatar_id': u'',
#    u'id': 29602928,
#    u'login': u'dmagee15',
#    u'url': u'https://api.github.com/users/dmagee15'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666789',
#   u'payload': {u'before': u'26cb0bc2e74e965ec2bf61f98fc841ddd20b7fba',
#    u'commits': [{u'author': {u'email': u'david.magee15@yahoo.com',
#       u'name': u'David M'},
#      u'distinct': True,
#      u'message': u'refined delete button styling',
#      u'sha': u'1e05d1092c51604cdd45ded06931db2aafa2a298',
#      u'url': u'https://api.github.com/repos/dmagee15/voting-app/commits/1e05d1092c51604cdd45ded06931db2aafa2a298'}],
#    u'distinct_size': 1,
#    u'head': u'1e05d1092c51604cdd45ded06931db2aafa2a298',
#    u'push_id': 2188013624L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 102065999,
#    u'name': u'dmagee15/voting-app',
#    u'url': u'https://api.github.com/repos/dmagee15/voting-app'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/12456438?',
#    u'display_login': u'qingziguanjun',
#    u'gravatar_id': u'',
#    u'id': 12456438,
#    u'login': u'qingziguanjun',
#    u'url': u'https://api.github.com/users/qingziguanjun'},
#   u'created_at': u'2017-12-12T02:05:03Z',
#   u'id': u'6974666787',
#   u'payload': {u'before': u'c916ec6c4298dfff3d45a02f1ff738093e3123d3',
#    u'commits': [{u'author': {u'email': u'songyi@internetware.cn',
#       u'name': u'songyi'},
#      u'distinct': True,
#      u'message': u'\u63d0\u4ea4',
#      u'sha': u'ff909409d992d1d4959ff29b22ff136bc62b5094',
#      u'url': u'https://api.github.com/repos/qingziguanjun/Articles/commits/ff909409d992d1d4959ff29b22ff136bc62b5094'}],
#    u'distinct_size': 1,
#    u'head': u'ff909409d992d1d4959ff29b22ff136bc62b5094',
#    u'push_id': 2188013622L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 110758089,
#    u'name': u'qingziguanjun/Articles',
#    u'url': u'https://api.github.com/repos/qingziguanjun/Articles'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/15459075?',
#    u'display_login': u'sjaymoon15',
#    u'gravatar_id': u'',
#    u'id': 15459075,
#    u'login': u'sjaymoon15',
#    u'url': u'https://api.github.com/users/sjaymoon15'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666786',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/33743425?',
#    u'gravatar_id': u'',
#    u'id': 33743425,
#    u'login': u'CupOfJoes',
#    u'url': u'https://api.github.com/orgs/CupOfJoes'},
#   u'payload': {u'action': u'closed',
#    u'number': 12,
#    u'pull_request': {u'_links': {u'comments': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/12/comments'},
#      u'commits': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12/commits'},
#      u'html': {u'href': u'https://github.com/CupOfJoes/CoffeeConnection/pull/12'},
#      u'issue': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/12'},
#      u'review_comment': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/comments{/number}'},
#      u'review_comments': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12/comments'},
#      u'self': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12'},
#      u'statuses': {u'href': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/statuses/694a26de93aa71691e9ef39d836c1dc345bb33ed'}},
#     u'additions': 70,
#     u'assignee': None,
#     u'assignees': [],
#     u'author_association': u'COLLABORATOR',
#     u'base': {u'label': u'CupOfJoes:develop',
#      u'ref': u'develop',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/{archive_format}{/ref}',
#       u'archived': False,
#       u'assignees_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/branches{/branch}',
#       u'clone_url': u'https://github.com/CupOfJoes/CoffeeConnection.git',
#       u'collaborators_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/contributors',
#       u'created_at': u'2017-11-17T05:48:43Z',
#       u'default_branch': u'develop',
#       u'deployments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/deployments',
#       u'description': u'Input your caffeinated beverage preferences so the company drink fetcher knows exactly what to get you!',
#       u'downloads_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/downloads',
#       u'events_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/events',
#       u'fork': False,
#       u'forks': 7,
#       u'forks_count': 7,
#       u'forks_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/forks',
#       u'full_name': u'CupOfJoes/CoffeeConnection',
#       u'git_commits_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/tags{/sha}',
#       u'git_url': u'git://github.com/CupOfJoes/CoffeeConnection.git',
#       u'has_downloads': True,
#       u'has_issues': True,
#       u'has_pages': False,
#       u'has_projects': True,
#       u'has_wiki': True,
#       u'homepage': None,
#       u'hooks_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/hooks',
#       u'html_url': u'https://github.com/CupOfJoes/CoffeeConnection',
#       u'id': 111063419,
#       u'issue_comment_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/labels{/name}',
#       u'language': u'JavaScript',
#       u'languages_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/languages',
#       u'license': None,
#       u'merges_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/merges',
#       u'milestones_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'CoffeeConnection',
#       u'notifications_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/notifications{?since,all,participating}',
#       u'open_issues': 1,
#       u'open_issues_count': 1,
#       u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/33743425?v=4',
#        u'events_url': u'https://api.github.com/users/CupOfJoes/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/CupOfJoes/followers',
#        u'following_url': u'https://api.github.com/users/CupOfJoes/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/CupOfJoes/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/CupOfJoes',
#        u'id': 33743425,
#        u'login': u'CupOfJoes',
#        u'organizations_url': u'https://api.github.com/users/CupOfJoes/orgs',
#        u'received_events_url': u'https://api.github.com/users/CupOfJoes/received_events',
#        u'repos_url': u'https://api.github.com/users/CupOfJoes/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/CupOfJoes/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/CupOfJoes/subscriptions',
#        u'type': u'Organization',
#        u'url': u'https://api.github.com/users/CupOfJoes'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls{/number}',
#       u'pushed_at': u'2017-12-12T02:05:02Z',
#       u'releases_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/releases{/id}',
#       u'size': 145,
#       u'ssh_url': u'git@github.com:CupOfJoes/CoffeeConnection.git',
#       u'stargazers_count': 1,
#       u'stargazers_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/subscription',
#       u'svn_url': u'https://github.com/CupOfJoes/CoffeeConnection',
#       u'tags_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/tags',
#       u'teams_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/teams',
#       u'trees_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/trees{/sha}',
#       u'updated_at': u'2017-11-22T17:03:47Z',
#       u'url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection',
#       u'watchers': 1,
#       u'watchers_count': 1},
#      u'sha': u'446a8f521469168cbe895bfde932d87509434f48',
#      u'user': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/33743425?v=4',
#       u'events_url': u'https://api.github.com/users/CupOfJoes/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/CupOfJoes/followers',
#       u'following_url': u'https://api.github.com/users/CupOfJoes/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/CupOfJoes/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/CupOfJoes',
#       u'id': 33743425,
#       u'login': u'CupOfJoes',
#       u'organizations_url': u'https://api.github.com/users/CupOfJoes/orgs',
#       u'received_events_url': u'https://api.github.com/users/CupOfJoes/received_events',
#       u'repos_url': u'https://api.github.com/users/CupOfJoes/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/CupOfJoes/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/CupOfJoes/subscriptions',
#       u'type': u'Organization',
#       u'url': u'https://api.github.com/users/CupOfJoes'}},
#     u'body': u'',
#     u'changed_files': 5,
#     u'closed_at': u'2017-12-12T02:05:02Z',
#     u'comments': 1,
#     u'comments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/12/comments',
#     u'commits': 9,
#     u'commits_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12/commits',
#     u'created_at': u'2017-12-08T13:49:10Z',
#     u'deletions': 57,
#     u'diff_url': u'https://github.com/CupOfJoes/CoffeeConnection/pull/12.diff',
#     u'head': {u'label': u'CupOfJoes:feature/update-schema',
#      u'ref': u'feature/update-schema',
#      u'repo': {u'archive_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/{archive_format}{/ref}',
#       u'archived': False,
#       u'assignees_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/assignees{/user}',
#       u'blobs_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/blobs{/sha}',
#       u'branches_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/branches{/branch}',
#       u'clone_url': u'https://github.com/CupOfJoes/CoffeeConnection.git',
#       u'collaborators_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/collaborators{/collaborator}',
#       u'comments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/comments{/number}',
#       u'commits_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/commits{/sha}',
#       u'compare_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/compare/{base}...{head}',
#       u'contents_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/contents/{+path}',
#       u'contributors_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/contributors',
#       u'created_at': u'2017-11-17T05:48:43Z',
#       u'default_branch': u'develop',
#       u'deployments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/deployments',
#       u'description': u'Input your caffeinated beverage preferences so the company drink fetcher knows exactly what to get you!',
#       u'downloads_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/downloads',
#       u'events_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/events',
#       u'fork': False,
#       u'forks': 7,
#       u'forks_count': 7,
#       u'forks_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/forks',
#       u'full_name': u'CupOfJoes/CoffeeConnection',
#       u'git_commits_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/commits{/sha}',
#       u'git_refs_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/refs{/sha}',
#       u'git_tags_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/tags{/sha}',
#       u'git_url': u'git://github.com/CupOfJoes/CoffeeConnection.git',
#       u'has_downloads': True,
#       u'has_issues': True,
#       u'has_pages': False,
#       u'has_projects': True,
#       u'has_wiki': True,
#       u'homepage': None,
#       u'hooks_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/hooks',
#       u'html_url': u'https://github.com/CupOfJoes/CoffeeConnection',
#       u'id': 111063419,
#       u'issue_comment_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/comments{/number}',
#       u'issue_events_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/events{/number}',
#       u'issues_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues{/number}',
#       u'keys_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/keys{/key_id}',
#       u'labels_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/labels{/name}',
#       u'language': u'JavaScript',
#       u'languages_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/languages',
#       u'license': None,
#       u'merges_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/merges',
#       u'milestones_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/milestones{/number}',
#       u'mirror_url': None,
#       u'name': u'CoffeeConnection',
#       u'notifications_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/notifications{?since,all,participating}',
#       u'open_issues': 1,
#       u'open_issues_count': 1,
#       u'owner': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/33743425?v=4',
#        u'events_url': u'https://api.github.com/users/CupOfJoes/events{/privacy}',
#        u'followers_url': u'https://api.github.com/users/CupOfJoes/followers',
#        u'following_url': u'https://api.github.com/users/CupOfJoes/following{/other_user}',
#        u'gists_url': u'https://api.github.com/users/CupOfJoes/gists{/gist_id}',
#        u'gravatar_id': u'',
#        u'html_url': u'https://github.com/CupOfJoes',
#        u'id': 33743425,
#        u'login': u'CupOfJoes',
#        u'organizations_url': u'https://api.github.com/users/CupOfJoes/orgs',
#        u'received_events_url': u'https://api.github.com/users/CupOfJoes/received_events',
#        u'repos_url': u'https://api.github.com/users/CupOfJoes/repos',
#        u'site_admin': False,
#        u'starred_url': u'https://api.github.com/users/CupOfJoes/starred{/owner}{/repo}',
#        u'subscriptions_url': u'https://api.github.com/users/CupOfJoes/subscriptions',
#        u'type': u'Organization',
#        u'url': u'https://api.github.com/users/CupOfJoes'},
#       u'private': False,
#       u'pulls_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls{/number}',
#       u'pushed_at': u'2017-12-12T02:05:02Z',
#       u'releases_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/releases{/id}',
#       u'size': 145,
#       u'ssh_url': u'git@github.com:CupOfJoes/CoffeeConnection.git',
#       u'stargazers_count': 1,
#       u'stargazers_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/stargazers',
#       u'statuses_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/statuses/{sha}',
#       u'subscribers_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/subscribers',
#       u'subscription_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/subscription',
#       u'svn_url': u'https://github.com/CupOfJoes/CoffeeConnection',
#       u'tags_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/tags',
#       u'teams_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/teams',
#       u'trees_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/git/trees{/sha}',
#       u'updated_at': u'2017-11-22T17:03:47Z',
#       u'url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection',
#       u'watchers': 1,
#       u'watchers_count': 1},
#      u'sha': u'694a26de93aa71691e9ef39d836c1dc345bb33ed',
#      u'user': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/33743425?v=4',
#       u'events_url': u'https://api.github.com/users/CupOfJoes/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/CupOfJoes/followers',
#       u'following_url': u'https://api.github.com/users/CupOfJoes/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/CupOfJoes/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/CupOfJoes',
#       u'id': 33743425,
#       u'login': u'CupOfJoes',
#       u'organizations_url': u'https://api.github.com/users/CupOfJoes/orgs',
#       u'received_events_url': u'https://api.github.com/users/CupOfJoes/received_events',
#       u'repos_url': u'https://api.github.com/users/CupOfJoes/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/CupOfJoes/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/CupOfJoes/subscriptions',
#       u'type': u'Organization',
#       u'url': u'https://api.github.com/users/CupOfJoes'}},
#     u'html_url': u'https://github.com/CupOfJoes/CoffeeConnection/pull/12',
#     u'id': 157246695,
#     u'issue_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/issues/12',
#     u'locked': False,
#     u'maintainer_can_modify': False,
#     u'merge_commit_sha': u'0c11074ec052c67ea41f27367768f1c26416dce8',
#     u'mergeable': None,
#     u'mergeable_state': u'unknown',
#     u'merged': True,
#     u'merged_at': u'2017-12-12T02:05:02Z',
#     u'merged_by': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/15459075?v=4',
#      u'events_url': u'https://api.github.com/users/sjaymoon15/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/sjaymoon15/followers',
#      u'following_url': u'https://api.github.com/users/sjaymoon15/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/sjaymoon15/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/sjaymoon15',
#      u'id': 15459075,
#      u'login': u'sjaymoon15',
#      u'organizations_url': u'https://api.github.com/users/sjaymoon15/orgs',
#      u'received_events_url': u'https://api.github.com/users/sjaymoon15/received_events',
#      u'repos_url': u'https://api.github.com/users/sjaymoon15/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/sjaymoon15/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/sjaymoon15/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/sjaymoon15'},
#     u'milestone': None,
#     u'number': 12,
#     u'patch_url': u'https://github.com/CupOfJoes/CoffeeConnection/pull/12.patch',
#     u'rebaseable': None,
#     u'requested_reviewers': [{u'avatar_url': u'https://avatars1.githubusercontent.com/u/1803843?v=4',
#       u'events_url': u'https://api.github.com/users/rouzbeh84/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/rouzbeh84/followers',
#       u'following_url': u'https://api.github.com/users/rouzbeh84/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/rouzbeh84/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/rouzbeh84',
#       u'id': 1803843,
#       u'login': u'rouzbeh84',
#       u'organizations_url': u'https://api.github.com/users/rouzbeh84/orgs',
#       u'received_events_url': u'https://api.github.com/users/rouzbeh84/received_events',
#       u'repos_url': u'https://api.github.com/users/rouzbeh84/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/rouzbeh84/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/rouzbeh84/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/rouzbeh84'},
#      {u'avatar_url': u'https://avatars3.githubusercontent.com/u/5395811?v=4',
#       u'events_url': u'https://api.github.com/users/jaimemendozadev/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/jaimemendozadev/followers',
#       u'following_url': u'https://api.github.com/users/jaimemendozadev/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/jaimemendozadev/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/jaimemendozadev',
#       u'id': 5395811,
#       u'login': u'jaimemendozadev',
#       u'organizations_url': u'https://api.github.com/users/jaimemendozadev/orgs',
#       u'received_events_url': u'https://api.github.com/users/jaimemendozadev/received_events',
#       u'repos_url': u'https://api.github.com/users/jaimemendozadev/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/jaimemendozadev/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/jaimemendozadev/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/jaimemendozadev'},
#      {u'avatar_url': u'https://avatars1.githubusercontent.com/u/17714293?v=4',
#       u'events_url': u'https://api.github.com/users/vvnsze/events{/privacy}',
#       u'followers_url': u'https://api.github.com/users/vvnsze/followers',
#       u'following_url': u'https://api.github.com/users/vvnsze/following{/other_user}',
#       u'gists_url': u'https://api.github.com/users/vvnsze/gists{/gist_id}',
#       u'gravatar_id': u'',
#       u'html_url': u'https://github.com/vvnsze',
#       u'id': 17714293,
#       u'login': u'vvnsze',
#       u'organizations_url': u'https://api.github.com/users/vvnsze/orgs',
#       u'received_events_url': u'https://api.github.com/users/vvnsze/received_events',
#       u'repos_url': u'https://api.github.com/users/vvnsze/repos',
#       u'site_admin': False,
#       u'starred_url': u'https://api.github.com/users/vvnsze/starred{/owner}{/repo}',
#       u'subscriptions_url': u'https://api.github.com/users/vvnsze/subscriptions',
#       u'type': u'User',
#       u'url': u'https://api.github.com/users/vvnsze'}],
#     u'review_comment_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/comments{/number}',
#     u'review_comments': 0,
#     u'review_comments_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12/comments',
#     u'state': u'closed',
#     u'statuses_url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/statuses/694a26de93aa71691e9ef39d836c1dc345bb33ed',
#     u'title': u'Feature/update schema',
#     u'updated_at': u'2017-12-12T02:05:02Z',
#     u'url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection/pulls/12',
#     u'user': {u'avatar_url': u'https://avatars3.githubusercontent.com/u/15459075?v=4',
#      u'events_url': u'https://api.github.com/users/sjaymoon15/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/sjaymoon15/followers',
#      u'following_url': u'https://api.github.com/users/sjaymoon15/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/sjaymoon15/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/sjaymoon15',
#      u'id': 15459075,
#      u'login': u'sjaymoon15',
#      u'organizations_url': u'https://api.github.com/users/sjaymoon15/orgs',
#      u'received_events_url': u'https://api.github.com/users/sjaymoon15/received_events',
#      u'repos_url': u'https://api.github.com/users/sjaymoon15/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/sjaymoon15/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/sjaymoon15/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/sjaymoon15'}}},
#   u'public': True,
#   u'repo': {u'id': 111063419,
#    u'name': u'CupOfJoes/CoffeeConnection',
#    u'url': u'https://api.github.com/repos/CupOfJoes/CoffeeConnection'},
#   u'type': u'PullRequestEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/22648562?',
#    u'display_login': u'gonzalezjo',
#    u'gravatar_id': u'',
#    u'id': 22648562,
#    u'login': u'gonzalezjo',
#    u'url': u'https://api.github.com/users/gonzalezjo'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666780',
#   u'payload': {u'before': u'8d9fccf188ea130135f841eb6d225a6cda36c3db',
#    u'commits': [{u'author': {u'email': u'gonzalezjo@users.noreply.github.com',
#       u'name': u'J. Gonzalez'},
#      u'distinct': True,
#      u'message': u'Update c_example.c',
#      u'sha': u'8ea8e468d41dcb28bff14038f6eba4eec077491f',
#      u'url': u'https://api.github.com/repos/gonzalezjo/lhashdos/commits/8ea8e468d41dcb28bff14038f6eba4eec077491f'}],
#    u'distinct_size': 1,
#    u'head': u'8ea8e468d41dcb28bff14038f6eba4eec077491f',
#    u'push_id': 2188013617L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 112775654,
#    u'name': u'gonzalezjo/lhashdos',
#    u'url': u'https://api.github.com/repos/gonzalezjo/lhashdos'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/3879547?',
#    u'display_login': u'laurajodz',
#    u'gravatar_id': u'',
#    u'id': 3879547,
#    u'login': u'laurajodz',
#    u'url': u'https://api.github.com/users/laurajodz'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666779',
#   u'payload': {u'before': u'5cdde371febacdfb28412559a19aaa1930b7519f',
#    u'commits': [{u'author': {u'email': u'laurajodz@gmail.com',
#       u'name': u'Laura Jodz'},
#      u'distinct': True,
#      u'message': u'initial commit',
#      u'sha': u'1cf7b180b527e157aa7342adc0c0d078552383f3',
#      u'url': u'https://api.github.com/repos/laurajodz/node-shopping-list-v2/commits/1cf7b180b527e157aa7342adc0c0d078552383f3'}],
#    u'distinct_size': 1,
#    u'head': u'1cf7b180b527e157aa7342adc0c0d078552383f3',
#    u'push_id': 2188013618L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 113925157,
#    u'name': u'laurajodz/node-shopping-list-v2',
#    u'url': u'https://api.github.com/repos/laurajodz/node-shopping-list-v2'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7200587?',
#    u'display_login': u'zhangluwei',
#    u'gravatar_id': u'',
#    u'id': 7200587,
#    u'login': u'zhangluwei',
#    u'url': u'https://api.github.com/users/zhangluwei'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666778',
#   u'payload': {u'before': u'ec7637be986e9c387de8b4224c7cd4080e005037',
#    u'commits': [{u'author': {u'email': u'z_lwei@qq.com', u'name': u'ippp'},
#      u'distinct': True,
#      u'message': u'send time Tue Dec 12 10:04:54 CST 2017',
#      u'sha': u'534e074a60531fbf598191501d9e7330b517f960',
#      u'url': u'https://api.github.com/repos/zhangluwei/boot/commits/534e074a60531fbf598191501d9e7330b517f960'}],
#    u'distinct_size': 1,
#    u'head': u'534e074a60531fbf598191501d9e7330b517f960',
#    u'push_id': 2188013615L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 111665219,
#    u'name': u'zhangluwei/boot',
#    u'url': u'https://api.github.com/repos/zhangluwei/boot'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8517910?',
#    u'display_login': u'LombiqBot',
#    u'gravatar_id': u'',
#    u'id': 8517910,
#    u'login': u'LombiqBot',
#    u'url': u'https://api.github.com/users/LombiqBot'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666776',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8158177?',
#    u'gravatar_id': u'',
#    u'id': 8158177,
#    u'login': u'Lombiq',
#    u'url': u'https://api.github.com/orgs/Lombiq'},
#   u'payload': {u'before': u'cd07ee3569199a368ce1f9919d885119ad59b195',
#    u'commits': [],
#    u'distinct_size': 0,
#    u'head': u'cd07ee3569199a368ce1f9919d885119ad59b195',
#    u'push_id': 2188013612L,
#    u'ref': u'refs/heads/jean/fix-link-to-sipkes-page-workcontextmd-e-1503913134867',
#    u'size': 0},
#   u'public': True,
#   u'repo': {u'id': 59599064,
#    u'name': u'Lombiq/Orchard-Dojo-Library',
#    u'url': u'https://api.github.com/repos/Lombiq/Orchard-Dojo-Library'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/32964275?',
#    u'display_login': u'PUNZ4LYFE',
#    u'gravatar_id': u'',
#    u'id': 32964275,
#    u'login': u'PUNZ4LYFE',
#    u'url': u'https://api.github.com/users/PUNZ4LYFE'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666771',
#   u'payload': {u'before': u'30a499bf5b54e9189aca46140d43ee9db231cf7b',
#    u'commits': [{u'author': {u'email': u'32964275+PUNZ4LYFE@users.noreply.github.com',
#       u'name': u'Karla Porras'},
#      u'distinct': True,
#      u'message': u'Update Animal.js',
#      u'sha': u'3cdfe05764a4da131995cb96e9019ee0797154fb',
#      u'url': u'https://api.github.com/repos/PUNZ4LYFE/kporrasLaGranja/commits/3cdfe05764a4da131995cb96e9019ee0797154fb'}],
#    u'distinct_size': 1,
#    u'head': u'3cdfe05764a4da131995cb96e9019ee0797154fb',
#    u'push_id': 2188013607L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 108486797,
#    u'name': u'PUNZ4LYFE/kporrasLaGranja',
#    u'url': u'https://api.github.com/repos/PUNZ4LYFE/kporrasLaGranja'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8517910?',
#    u'display_login': u'LombiqBot',
#    u'gravatar_id': u'',
#    u'id': 8517910,
#    u'login': u'LombiqBot',
#    u'url': u'https://api.github.com/users/LombiqBot'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666769',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8158177?',
#    u'gravatar_id': u'',
#    u'id': 8158177,
#    u'login': u'Lombiq',
#    u'url': u'https://api.github.com/orgs/Lombiq'},
#   u'payload': {u'before': u'9090ab7ac04af72a58fe0492547e5456cd45d37f',
#    u'commits': [],
#    u'distinct_size': 0,
#    u'head': u'9090ab7ac04af72a58fe0492547e5456cd45d37f',
#    u'push_id': 2188013605L,
#    u'ref': u'refs/heads/orchard-upgrade-1.10',
#    u'size': 0},
#   u'public': True,
#   u'repo': {u'id': 46596436,
#    u'name': u'Lombiq/Orchard-Download-As',
#    u'url': u'https://api.github.com/repos/Lombiq/Orchard-Download-As'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/2039910?',
#    u'display_login': u'miniers',
#    u'gravatar_id': u'',
#    u'id': 2039910,
#    u'login': u'miniers',
#    u'url': u'https://api.github.com/users/miniers'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666757',
#   u'payload': {u'forkee': {u'archive_url': u'https://api.github.com/repos/miniers/vscode-jsbox/{archive_format}{/ref}',
#     u'archived': False,
#     u'assignees_url': u'https://api.github.com/repos/miniers/vscode-jsbox/assignees{/user}',
#     u'blobs_url': u'https://api.github.com/repos/miniers/vscode-jsbox/git/blobs{/sha}',
#     u'branches_url': u'https://api.github.com/repos/miniers/vscode-jsbox/branches{/branch}',
#     u'clone_url': u'https://github.com/miniers/vscode-jsbox.git',
#     u'collaborators_url': u'https://api.github.com/repos/miniers/vscode-jsbox/collaborators{/collaborator}',
#     u'comments_url': u'https://api.github.com/repos/miniers/vscode-jsbox/comments{/number}',
#     u'commits_url': u'https://api.github.com/repos/miniers/vscode-jsbox/commits{/sha}',
#     u'compare_url': u'https://api.github.com/repos/miniers/vscode-jsbox/compare/{base}...{head}',
#     u'contents_url': u'https://api.github.com/repos/miniers/vscode-jsbox/contents/{+path}',
#     u'contributors_url': u'https://api.github.com/repos/miniers/vscode-jsbox/contributors',
#     u'created_at': u'2017-12-12T02:05:02Z',
#     u'default_branch': u'master',
#     u'deployments_url': u'https://api.github.com/repos/miniers/vscode-jsbox/deployments',
#     u'description': u'JSBox Development Utilities on VSCode',
#     u'downloads_url': u'https://api.github.com/repos/miniers/vscode-jsbox/downloads',
#     u'events_url': u'https://api.github.com/repos/miniers/vscode-jsbox/events',
#     u'fork': True,
#     u'forks': 0,
#     u'forks_count': 0,
#     u'forks_url': u'https://api.github.com/repos/miniers/vscode-jsbox/forks',
#     u'full_name': u'miniers/vscode-jsbox',
#     u'git_commits_url': u'https://api.github.com/repos/miniers/vscode-jsbox/git/commits{/sha}',
#     u'git_refs_url': u'https://api.github.com/repos/miniers/vscode-jsbox/git/refs{/sha}',
#     u'git_tags_url': u'https://api.github.com/repos/miniers/vscode-jsbox/git/tags{/sha}',
#     u'git_url': u'git://github.com/miniers/vscode-jsbox.git',
#     u'has_downloads': True,
#     u'has_issues': False,
#     u'has_pages': False,
#     u'has_projects': True,
#     u'has_wiki': True,
#     u'homepage': None,
#     u'hooks_url': u'https://api.github.com/repos/miniers/vscode-jsbox/hooks',
#     u'html_url': u'https://github.com/miniers/vscode-jsbox',
#     u'id': 113930908,
#     u'issue_comment_url': u'https://api.github.com/repos/miniers/vscode-jsbox/issues/comments{/number}',
#     u'issue_events_url': u'https://api.github.com/repos/miniers/vscode-jsbox/issues/events{/number}',
#     u'issues_url': u'https://api.github.com/repos/miniers/vscode-jsbox/issues{/number}',
#     u'keys_url': u'https://api.github.com/repos/miniers/vscode-jsbox/keys{/key_id}',
#     u'labels_url': u'https://api.github.com/repos/miniers/vscode-jsbox/labels{/name}',
#     u'language': None,
#     u'languages_url': u'https://api.github.com/repos/miniers/vscode-jsbox/languages',
#     u'license': None,
#     u'merges_url': u'https://api.github.com/repos/miniers/vscode-jsbox/merges',
#     u'milestones_url': u'https://api.github.com/repos/miniers/vscode-jsbox/milestones{/number}',
#     u'mirror_url': None,
#     u'name': u'vscode-jsbox',
#     u'notifications_url': u'https://api.github.com/repos/miniers/vscode-jsbox/notifications{?since,all,participating}',
#     u'open_issues': 0,
#     u'open_issues_count': 0,
#     u'owner': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/2039910?v=4',
#      u'events_url': u'https://api.github.com/users/miniers/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/miniers/followers',
#      u'following_url': u'https://api.github.com/users/miniers/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/miniers/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/miniers',
#      u'id': 2039910,
#      u'login': u'miniers',
#      u'organizations_url': u'https://api.github.com/users/miniers/orgs',
#      u'received_events_url': u'https://api.github.com/users/miniers/received_events',
#      u'repos_url': u'https://api.github.com/users/miniers/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/miniers/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/miniers/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/miniers'},
#     u'private': False,
#     u'public': True,
#     u'pulls_url': u'https://api.github.com/repos/miniers/vscode-jsbox/pulls{/number}',
#     u'pushed_at': u'2017-12-08T16:21:30Z',
#     u'releases_url': u'https://api.github.com/repos/miniers/vscode-jsbox/releases{/id}',
#     u'size': 50,
#     u'ssh_url': u'git@github.com:miniers/vscode-jsbox.git',
#     u'stargazers_count': 0,
#     u'stargazers_url': u'https://api.github.com/repos/miniers/vscode-jsbox/stargazers',
#     u'statuses_url': u'https://api.github.com/repos/miniers/vscode-jsbox/statuses/{sha}',
#     u'subscribers_url': u'https://api.github.com/repos/miniers/vscode-jsbox/subscribers',
#     u'subscription_url': u'https://api.github.com/repos/miniers/vscode-jsbox/subscription',
#     u'svn_url': u'https://github.com/miniers/vscode-jsbox',
#     u'tags_url': u'https://api.github.com/repos/miniers/vscode-jsbox/tags',
#     u'teams_url': u'https://api.github.com/repos/miniers/vscode-jsbox/teams',
#     u'trees_url': u'https://api.github.com/repos/miniers/vscode-jsbox/git/trees{/sha}',
#     u'updated_at': u'2017-12-09T01:26:37Z',
#     u'url': u'https://api.github.com/repos/miniers/vscode-jsbox',
#     u'watchers': 0,
#     u'watchers_count': 0}},
#   u'public': True,
#   u'repo': {u'id': 113593792,
#    u'name': u'cyanzhong/vscode-jsbox',
#    u'url': u'https://api.github.com/repos/cyanzhong/vscode-jsbox'},
#   u'type': u'ForkEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/24579094?',
#    u'display_login': u'whyalike',
#    u'gravatar_id': u'',
#    u'id': 24579094,
#    u'login': u'whyalike',
#    u'url': u'https://api.github.com/users/whyalike'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666756',
#   u'payload': {u'before': u'0529ae948fdc078ec54cb882caf436ef82627e86',
#    u'commits': [{u'author': {u'email': u'alikachoo5@gmail.com',
#       u'name': u'Alika Choo'},
#      u'distinct': True,
#      u'message': u'Add edit, update, show and index listings',
#      u'sha': u'ac001f41f82682b8c085e9b5ccb0409e5bdd3056',
#      u'url': u'https://api.github.com/repos/whyalike/alpha-blog/commits/ac001f41f82682b8c085e9b5ccb0409e5bdd3056'}],
#    u'distinct_size': 1,
#    u'head': u'ac001f41f82682b8c085e9b5ccb0409e5bdd3056',
#    u'push_id': 2188013599L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 110970475,
#    u'name': u'whyalike/alpha-blog',
#    u'url': u'https://api.github.com/repos/whyalike/alpha-blog'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/34326066?',
#    u'display_login': u'steveranta',
#    u'gravatar_id': u'',
#    u'id': 34326066,
#    u'login': u'steveranta',
#    u'url': u'https://api.github.com/users/steveranta'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666754',
#   u'payload': {u'before': u'9bca76011c9fe19d28946301989da67081c0ef48',
#    u'commits': [{u'author': {u'email': u'34326066+steveranta@users.noreply.github.com',
#       u'name': u'steveranta'},
#      u'distinct': True,
#      u'message': u'Add files via upload',
#      u'sha': u'cc3a325981591489b05bc28c82548d29570ca0ae',
#      u'url': u'https://api.github.com/repos/steveranta/VR-Collection/commits/cc3a325981591489b05bc28c82548d29570ca0ae'}],
#    u'distinct_size': 1,
#    u'head': u'cc3a325981591489b05bc28c82548d29570ca0ae',
#    u'push_id': 2188013598L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 113732671,
#    u'name': u'steveranta/VR-Collection',
#    u'url': u'https://api.github.com/repos/steveranta/VR-Collection'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/31112440?',
#    u'display_login': u'kaktuxmx',
#    u'gravatar_id': u'',
#    u'id': 31112440,
#    u'login': u'kaktuxmx',
#    u'url': u'https://api.github.com/users/kaktuxmx'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666752',
#   u'payload': {u'action': u'added',
#    u'member': {u'avatar_url': u'https://avatars2.githubusercontent.com/u/31899881?v=4',
#     u'events_url': u'https://api.github.com/users/LandonRichards/events{/privacy}',
#     u'followers_url': u'https://api.github.com/users/LandonRichards/followers',
#     u'following_url': u'https://api.github.com/users/LandonRichards/following{/other_user}',
#     u'gists_url': u'https://api.github.com/users/LandonRichards/gists{/gist_id}',
#     u'gravatar_id': u'',
#     u'html_url': u'https://github.com/LandonRichards',
#     u'id': 31899881,
#     u'login': u'LandonRichards',
#     u'organizations_url': u'https://api.github.com/users/LandonRichards/orgs',
#     u'received_events_url': u'https://api.github.com/users/LandonRichards/received_events',
#     u'repos_url': u'https://api.github.com/users/LandonRichards/repos',
#     u'site_admin': False,
#     u'starred_url': u'https://api.github.com/users/LandonRichards/starred{/owner}{/repo}',
#     u'subscriptions_url': u'https://api.github.com/users/LandonRichards/subscriptions',
#     u'type': u'User',
#     u'url': u'https://api.github.com/users/LandonRichards'}},
#   u'public': True,
#   u'repo': {u'id': 113930188,
#    u'name': u'kaktuxmx/PreGame-App',
#    u'url': u'https://api.github.com/repos/kaktuxmx/PreGame-App'},
#   u'type': u'MemberEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1686007?',
#    u'display_login': u'efarbereger',
#    u'gravatar_id': u'',
#    u'id': 1686007,
#    u'login': u'efarbereger',
#    u'url': u'https://api.github.com/users/efarbereger'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666750',
#   u'payload': {u'description': u'makes a fun clock',
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': None,
#    u'ref_type': u'repository'},
#   u'public': True,
#   u'repo': {u'id': 113930907,
#    u'name': u'efarbereger/historyclockimage',
#    u'url': u'https://api.github.com/repos/efarbereger/historyclockimage'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/8045818?',
#    u'display_login': u'drizzersilverberg',
#    u'gravatar_id': u'',
#    u'id': 8045818,
#    u'login': u'drizzersilverberg',
# ...
#      u'sha': u'ab90cfab3cf3e663d45c9491acd8345610127b93',
#      u'url': u'https://api.github.com/repos/BerkanR/Programacion/commits/ab90cfab3cf3e663d45c9491acd8345610127b93'}],
#    u'distinct_size': 1,
#    u'head': u'ab90cfab3cf3e663d45c9491acd8345610127b93',
#    u'push_id': 2188013592L,
#    u'ref': u'refs/heads/master',
#    u'size': 1},
#   u'public': True,
#   u'repo': {u'id': 113924289,
#    u'name': u'BerkanR/Programacion',
#    u'url': u'https://api.github.com/repos/BerkanR/Programacion'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/6805?',
#    u'display_login': u'rgm',
#    u'gravatar_id': u'',
#    u'id': 6805,
#    u'login': u'rgm',
#    u'url': u'https://api.github.com/users/rgm'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666742',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/25515882?',
#    u'gravatar_id': u'',
#    u'id': 25515882,
#    u'login': u'opengreenbuilding',
#    u'url': u'https://api.github.com/orgs/opengreenbuilding'},
#   u'payload': {u'before': u'28fc2b481d18aa68d63cb751982aa4b7b3f0a253',
#    u'commits': [{u'author': {u'email': u'ryan@ryanmccuaig.net',
#       u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'Turn pint columns on in the UI',
#      u'sha': u'45e425f4cab53a477cbbedc36c486a794f433294',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/45e425f4cab53a477cbbedc36c486a794f433294'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Adds weird Toronto units choice to mapping, data quality\n\nGot some sample data from City of Toronto suggesting that they might\nneed to pull in data that's partially US-customary, partially metric.",
#      u'sha': u'd2d9272d906d38c29898de9212b5dc0978e0bad0',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/d2d9272d906d38c29898de9212b5dc0978e0bad0'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Stub in `$translate.instant`\n\nThe OGBS translation PR isn't yet accepted but we know it's coming. So\nstub in translation as a no-op and tag things appropriately to avoid\nhaving to do some picky work at merge time.",
#      u'sha': u'fb6ef38d20cdf954641cfd7fe43a8ef79fa43453',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/fb6ef38d20cdf954641cfd7fe43a8ef79fa43453'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Sketch in measurement units settings interface\n\nThis'll be an org-level preference so that Django can know about it,\nmeaning Django can feed out data in the preferred format and we can\ngenerally avoid cluttering up the Angular side of things with tagged\nobjects.",
#      u'sha': u'1726e964e592e937b816955f5b44b1e1f9694ba1',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/1726e964e592e937b816955f5b44b1e1f9694ba1'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'Adds display units preferences to the Organization model\n\nHave decided to store these as Pint strings instead of ints to reduce\nthe indirection involved in reading code. Generally these are fixed\nvalues being submitted through and can be clamped using standard\nvalidation.\n\nThe default value reflects the current state of affairs for existing\nSEED production instances and should be suitable (ie. there are no UI\nchoices other that ft\xb2 and kBtu/ft\xb2/year).\n\nThis commit both starts feeding out the preferences and handles writing\nthem back into the database.',
#      u'sha': u'6665ac4436a8d8dc0289bf940b2739c427a2f8c3',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/6665ac4436a8d8dc0289bf940b2739c427a2f8c3'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"wip sprout to de-dimension\n\nHave to handle this before it hits the serializer since I can't quite\nfigure out how to parameterize the serializer itself. All we get to pass\nto `JsonResponse` is a class name. (Maybe some function that produces a\nclass, like `JsonResponse(my_stuff,encoder=PintSerializer(org))` )",
#      u'sha': u'536f189fae31f9da9a44540f967505cd2e366984',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/536f189fae31f9da9a44540f967505cd2e366984'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'Bump flipper expiry back past 2.3 release date',
#      u'sha': u'ac1c30e5437e90435ae85ecb505b560812b7a72d',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/ac1c30e5437e90435ae85ecb505b560812b7a72d'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Adds the display units to the column heads in ui-grid\n\nTack on the organization's display units before sending these out on the\ncolumn info API, and the ui-grids will pick it up. This is in keeping\nwith the general strategy of having Angular know nothing in particular\nabout the organization's choice of units and simply handling it on the\nserver side.\n\nStill needs a converter from pint spec->display string.",
#      u'sha': u'264ca22cb692a433dfcd9cddd86de9ba53cd5384',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/264ca22cb692a433dfcd9cddd86de9ba53cd5384'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Collapses quantities->floats before sending out inventory data\n\nThis can't easily be handled by a serializer, since the serializer needs\nto be specialized by with some Org-level preferences. Adds a collapsing\nfunction and maps it over the outbound property/taxlot dicts to convert\nevery Quantity object found to a straight float in the Org's preferred\nunits. Supercedes 0acd9a80.",
#      u'sha': u'f99de48bc519d1de2da992122d4cc44f56d5f810',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/f99de48bc519d1de2da992122d4cc44f56d5f810'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'Use the org_id defined above\n\nThe org_id above has already been KeyError-guarded, etc. instead of just\nusing straight nested access on `request.` This is a bit less coupled to\nrequest.',
#      u'sha': u'fca2383bf69b2ad69e4a4cf9ca538978e0f57684',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/fca2383bf69b2ad69e4a4cf9ca538978e0f57684'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Moves pretty_units to the bag of pint formatter functions\n\nSerializers probably isn't the permanent home of this stuff.",
#      u'sha': u'96c01479a030f856d2f1b7240abec3ee2fbb9a55',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/96c01479a030f856d2f1b7240abec3ee2fbb9a55'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Prettifies the ui-grid column headers and strips off `(Pint)`\n\nWhen we swap the old columns out and the new Pint-aware columns in,\nwe'll not (presumably) need to strip the `(Pint)` off the tail end of\nthe display title. Even in the intermediate period, though, we haven't\nlost the ability to tell which columns are Pint-aware, since this now\nmanifests in the UI as a column name with the units tacked on.",
#      u'sha': u'68f7166f0c7d649ba6a4fc28316c5cd5c892186c',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/68f7166f0c7d649ba6a4fc28316c5cd5c892186c'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'flake8',
#      u'sha': u'67a1b02cd188ac34f1275ecbd4cd4799382fd4bf',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/67a1b02cd188ac34f1275ecbd4cd4799382fd4bf'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u'flake8',
#      u'sha': u'41c22d554ebfb691f06039c42c9a50a3ad4c4b83',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/41c22d554ebfb691f06039c42c9a50a3ad4c4b83'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': False,
#      u'message': u"Fixes tests to account for unit display pref defaults\n\nI'm not entirely sure here why Unicode started coming out of these\nmethods; have applied a band-aid and will check on Travis.",
#      u'sha': u'2defebf6ea979f18530f606b385903b388fc9162',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/2defebf6ea979f18530f606b385903b388fc9162'},
#     {u'author': {u'email': u'ryan@ryanmccuaig.net', u'name': u'Ryan McCuaig'},
#      u'distinct': True,
#      u'message': u'Fix no-os warning in config/settings/test',
#      u'sha': u'4c6bc576fee2eaf32346938e92745b01503d5ef3',
#      u'url': u'https://api.github.com/repos/opengreenbuilding/seed/commits/4c6bc576fee2eaf32346938e92745b01503d5ef3'}],
#    u'distinct_size': 1,
#    u'head': u'4c6bc576fee2eaf32346938e92745b01503d5ef3',
#    u'push_id': 2188013590L,
#    u'ref': u'refs/heads/metric-wip',
#    u'size': 16},
#   u'public': True,
#   u'repo': {u'id': 80769336,
#    u'name': u'opengreenbuilding/seed',
#    u'url': u'https://api.github.com/repos/opengreenbuilding/seed'},
#   u'type': u'PushEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/17427345?',
#    u'display_login': u'shomatan',
#    u'gravatar_id': u'',
#    u'id': 17427345,
#    u'login': u'shomatan',
#    u'url': u'https://api.github.com/users/shomatan'},
#   u'created_at': u'2017-12-12T02:05:02Z',
#   u'id': u'6974666738',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/462626?',
#    u'gravatar_id': u'',
#    u'id': 462626,
#    u'login': u'nulab',
#    u'url': u'https://api.github.com/orgs/nulab'},
#   u'payload': {u'description': u'Migrate your projects from Redmine to Backlog.',
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': u'Fix-mixpanel-env',
#    u'ref_type': u'branch'},
#   u'public': True,
#   u'repo': {u'id': 44598044,
#    u'name': u'nulab/BacklogMigration-Redmine',
#    u'url': u'https://api.github.com/repos/nulab/BacklogMigration-Redmine'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/20172538?',
#    u'display_login': u'josephmancuso',
#    u'gravatar_id': u'',
#    u'id': 20172538,
#    u'login': u'josephmancuso',
#    u'url': u'https://api.github.com/users/josephmancuso'},
#   u'created_at': u'2017-12-12T02:05:01Z',
#   u'id': u'6974666737',
#   u'payload': {u'action': u'opened',
#    u'issue': {u'assignee': None,
#     u'assignees': [],
#     u'author_association': u'OWNER',
#     u'body': u"Need a way to pass url segments into the view:\r\n\r\nThis URL: `/some/{url}/{here}` should pass `url = value` and `here = value` into the view. or a dictionary, or just inside the the `Request` object and fetched with something like `request.segment('value')`\r\n\r\n*Implementation of this should be discusses via the pull request*",
#     u'closed_at': None,
#     u'comments': 0,
#     u'comments_url': u'https://api.github.com/repos/josephmancuso/python-framework/issues/3/comments',
#     u'created_at': u'2017-12-12T02:05:01Z',
#     u'events_url': u'https://api.github.com/repos/josephmancuso/python-framework/issues/3/events',
#     u'html_url': u'https://github.com/josephmancuso/python-framework/issues/3',
#     u'id': 281231874,
#     u'labels': [],
#     u'labels_url': u'https://api.github.com/repos/josephmancuso/python-framework/issues/3/labels{/name}',
#     u'locked': False,
#     u'milestone': None,
#     u'number': 3,
#     u'repository_url': u'https://api.github.com/repos/josephmancuso/python-framework',
#     u'state': u'open',
#     u'title': u'Ability to retrieve URL segments',
#     u'updated_at': u'2017-12-12T02:05:01Z',
#     u'url': u'https://api.github.com/repos/josephmancuso/python-framework/issues/3',
#     u'user': {u'avatar_url': u'https://avatars1.githubusercontent.com/u/20172538?v=4',
#      u'events_url': u'https://api.github.com/users/josephmancuso/events{/privacy}',
#      u'followers_url': u'https://api.github.com/users/josephmancuso/followers',
#      u'following_url': u'https://api.github.com/users/josephmancuso/following{/other_user}',
#      u'gists_url': u'https://api.github.com/users/josephmancuso/gists{/gist_id}',
#      u'gravatar_id': u'',
#      u'html_url': u'https://github.com/josephmancuso',
#      u'id': 20172538,
#      u'login': u'josephmancuso',
#      u'organizations_url': u'https://api.github.com/users/josephmancuso/orgs',
#      u'received_events_url': u'https://api.github.com/users/josephmancuso/received_events',
#      u'repos_url': u'https://api.github.com/users/josephmancuso/repos',
#      u'site_admin': False,
#      u'starred_url': u'https://api.github.com/users/josephmancuso/starred{/owner}{/repo}',
#      u'subscriptions_url': u'https://api.github.com/users/josephmancuso/subscriptions',
#      u'type': u'User',
#      u'url': u'https://api.github.com/users/josephmancuso'}}},
#   u'public': True,
#   u'repo': {u'id': 113248605,
#    u'name': u'josephmancuso/python-framework',
#    u'url': u'https://api.github.com/repos/josephmancuso/python-framework'},
#   u'type': u'IssuesEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/1036677?',
#    u'display_login': u'fusesource-ci',
#    u'gravatar_id': u'',
#    u'id': 1036677,
#    u'login': u'fusesource-ci',
#    u'url': u'https://api.github.com/users/fusesource-ci'},
#   u'created_at': u'2017-12-12T02:05:01Z',
#   u'id': u'6974666734',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/7937746?',
#    u'gravatar_id': u'',
#    u'id': 7937746,
#    u'login': u'wildfly-extras',
#    u'url': u'https://api.github.com/orgs/wildfly-extras'},
#   u'payload': {u'description': u'The WildFly-Camel Examples',
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': u'wildfly-camel-examples-5.0.0.fuse-000008',
#    u'ref_type': u'tag'},
#   u'public': True,
#   u'repo': {u'id': 65549772,
#    u'name': u'wildfly-extras/wildfly-camel-examples',
#    u'url': u'https://api.github.com/repos/wildfly-extras/wildfly-camel-examples'},
#   u'type': u'CreateEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/11440627?',
#    u'display_login': u'tanghuan',
#    u'gravatar_id': u'',
#    u'id': 11440627,
#    u'login': u'tanghuan',
#    u'url': u'https://api.github.com/users/tanghuan'},
#   u'created_at': u'2017-12-12T02:05:01Z',
#   u'id': u'6974666721',
#   u'org': {u'avatar_url': u'https://avatars.githubusercontent.com/u/22252348?',
#    u'gravatar_id': u'',
#    u'id': 22252348,
#    u'login': u'getinsomnia',
#    u'url': u'https://api.github.com/orgs/getinsomnia'},
#   u'payload': {u'action': u'started'},
#   u'public': True,
#   u'repo': {u'id': 56899284,
#    u'name': u'getinsomnia/insomnia',
#    u'url': u'https://api.github.com/repos/getinsomnia/insomnia'},
#   u'type': u'WatchEvent'},
#  {u'actor': {u'avatar_url': u'https://avatars.githubusercontent.com/u/34140472?',
#    u'display_login': u'nwgrubaugh',
#    u'gravatar_id': u'',
#    u'id': 34140472,
#    u'login': u'nwgrubaugh',
#    u'url': u'https://api.github.com/users/nwgrubaugh'},
#   u'created_at': u'2017-12-12T02:05:01Z',
#   u'id': u'6974666720',
#   u'payload': {u'description': u'A text repo to put all of out CADET Django code before we push it to Phabricator.',
#    u'master_branch': u'master',
#    u'pusher_type': u'user',
#    u'ref': u'nick-documentation-updates',
#    u'ref_type': u'branch'},
#   u'public': True,
#   u'repo': {u'id': 107023877,
#    u'name': u'AshleyMorse/CADET_Sandbox',
#    u'url': u'https://api.github.com/repos/AshleyMorse/CADET_Sandbox'},
#   u'type': u'CreateEvent'}]

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# Raw Response Content

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# '\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03'

# %% [markdown]
# You should use a pattern like this to save what is being streamed to a file:

# %%
#with open(filename, 'wb') as fd:
#    for chunk in r.iter_content(chunk_size=128):
#        fd.write(chunk)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-0099927e8504> in <module>()
# ----> 1 with open(filename, 'wb') as fd:
#       2     for chunk in r.iter_content(chunk_size=128):
#       3         fd.write(chunk)
#
# NameError: name 'filename' is not defined
